# %%
cart = ['노트북', "마우스", "키보드"]
cart
# Out:
# ['노트북', '마우스', '키보드']

# %%
cart[1] = "무선 마우스" 
cart
# Out:
# ['노트북', '무선 마우스', '키보드']

# %%
location = (37.5665, 126.9780)
location
# Out:
# (37.5665, 126.978)

# %%
sales = [120, 150, 110, 180, 200]
print(sales[-1])
# Out:
# 200

# %%
sales = [120, 150, 110, 180, 200, 170]
print(sales[1:4])
# Out:
# [150, 110, 180]

# %%
dates = ["8/1", "8/2", "8/3", "8/4", "8/5"]
print(dates[::-1])
# Out:
# ['8/5', '8/4', '8/3', '8/2', '8/1']

# %%
team_a = ["민수", "지수"]
team_b = ["철수", "영희"]

team = team_a + team_b
print(team)
# Out:
# ['민수', '지수', '철수', '영희']

# %%
users = ["kim", "lee", "park", "choi", "jung"]

len(users)
# Out:
# 5

# %%
user_roles = ["editor", "member", "admin"]
print("admin" in user_roles)
print("file" in user_roles)
# Out:
# True
# False

# %%
user = "민수", 25, "데이터 분석가"

print(user)
# Out:
# ('민수', 25, '데이터 분석가')

# %%
name, age, job = user
print(name)
print(age)
print(job)
# Out:
# 민수
# 25
# 데이터 분석가

# %%
user = {"name":"민수", "age":"25", "grade":"gold"}
print(user)
# Out:
# {'name': '민수', 'age': '25', 'grade': 'gold'}

# %%
user["grade"]
# Out:
# 'gold'

# %%
user["age"]=26
user["email"] = "minsu@example.com"
user
# Out:
# {'name': '민수', 'age': 26, 'grade': 'gold', 'email': 'minsu@example.com'}

# %%
menu = {
    "coffee": 4000,
    "tea": 4500,
    "juice": 5000
}

print(menu.keys())
print(menu.values())

price = menu.get("smoothie", 6000)
print(price)
# Out:
# dict_keys(['coffee', 'tea', 'juice'])
# dict_values([4000, 4500, 5000])
# 6000

# %%
visitors = set([101, 102, 101, 103, 102, 104])

visitors
# Out:
# {101, 102, 103, 104}

# %%
event_a = {101, 102, 103, 104}
event_b = {103, 104, 105, 106}

event = event_a & event_b

print(event)
# Out:
# {104, 103}

# %%
event_a = {101, 102, 103, 104}
event_b = {103, 104, 105, 106}

all = event_a | event_b
print(all)
# Out:
# {101, 102, 103, 104, 105, 106}

# %%
order_price = 65000

if order_price >= 50000:
    print("무료 배송 대상입니다.")
# Out:
# 무료 배송 대상입니다.

# %%
user_role = "admin"

if user_role=="admin":
    print("관리자 페이지에 접근합니다.")
# Out:
# 관리자 페이지에 접근합니다.

# %%
x = -1

if x:
    print('hi')
# Out:
# hi

# %%
age = 18

if age >= 20:
    print("성인 인증이 완료되었습니다.")
else:
    print("미성년자는 접근할 수 없습니다.")
# Out:
# 미성년자는 접근할 수 없습니다.

# %%
age = 18

if age >= 20:
    print("접근 가능합니다.")
else:
    print("접근할 수 없습니다.")
# Out:
# 접근할 수 없습니다.

# %%
stock = 0

if stock >=1:
    print("주문 가능합니다.")
else:
    print("품절된 상품입니다.")
# Out:
# 품절된 상품입니다.

# %%
is_logged_in = True
has_permission = True

if is_logged_in and has_permission:
    print("관리자 대시보드 진입")
# Out:
# 관리자 대시보드 진입

# %%
is_logged_in = True
is_admin = True

if is_logged_in:
    if is_admin:
        print("관리자 페이지에 접근합니다.")
# Out:
# 관리자 페이지에 접근합니다.

# %%
is_logged_in = True
is_admin = True

if is_logged_in and is_admin:
    print("관리자 페이지에 접근합니다.")
# Out:
# 관리자 페이지에 접근합니다.
